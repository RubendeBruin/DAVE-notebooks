# %% [markdown]
# # This is a test-notebook to see of the rendering works
#
# This should produce both an interactive 3D view and a screenshow

# %%
from DAVE.scene import Scene
# Out:
# default resource folders:
# /opt/tljh/user/lib/python3.6/site-packages/DAVE/resources
# /home/jupyter-dave/DAVE_models

# %%
from DAVE.jupyter import *

# %%
s = Scene()
s.new_rigidbody('test')

# %%
show(s)
# Out:
# Plot(antialias=3, axes=['x', 'y', 'z'], axes_helper=1.0, background_color=16777215, camera=[14.142147078856167…

# %%
screenshot(s)
