# %%
from DAVE import *
# %gui qt
# Out:
# Equilibrium-core version = 1.05
# default resource folders:
# C:\Users\beneden\Miniconda3\envs\DAVE\lib\site-packages\DAVE\resources
# C:\Users\beneden\DAVE_models
# C:\data\Dave\Public\DAVE-notebooks\99 Technical tests
# Blender found at: C:\Program Files\Blender Foundation\Blender 2.83\blender.exe

# %% [markdown]
# # Header

# %% [markdown]
# $e^{i\pi} + 1 = 0$

# %%
s = Scene()

# %%
s.import_scene(r'C:/Users/beneden/DAVE_models/basic_lift.dave')
# Out:
# Loading C:\Users\beneden\DAVE_models\basic_lift.dave
# import_container <'DAVE.scene.Axis>

# %%
from DAVE.gui import *
# Out:
# embedWindow(verbose=True): could not load k3d module, try:
# > pip install k3d      # and if necessary:
# > conda install nodejs

# %%
g = Gui(s, block=False)
# Out:
# Creating Node Tree
# Creating Derived Properties
# Creating Properties
# Creating Rigg-it-Right

# %%
from DAVE.jupyter import *
show(s, sea = False, camera_pos = (11.987908662977306, -12.51737413541265, 7.001250278668547), lookat = (0.5408384684333156, -1.070303940868658, 1.2777151813965397),visual_alpha = 0.42, force_normalize = True, force_scale = 1.6, cog_scale = 0.25)
# Out:
# <PIL.Image.Image image mode=RGB size=3072x1800 at 0x24E9CCAA5E0>

# %%
new_scene = Scene()
# Out:
# -- closing the gui : these were the actions you performed while the gui was open --

# %%
new_scene.new_point('test_newscene')
# Out:
# test_newscene <'DAVE.scene.Point>

# %%
s['Axis'].global_rotation
# Out:
# -- closing the gui : these were the actions you performed while the gui was open --
#
# import_container [Axis]
#  |-> test [RigidBody]
#  |    |-> Visual [Visual]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-ebba68871a79> in <module>
# ----> 1 s['Axis'].global_rotation
#
# ~\Miniconda3\envs\DAVE\lib\site-packages\DAVE\scene.py in __getitem__(self, node_name)
#    5147     def __getitem__(self, node_name):
#    5148         """Returns a node with name"""
# -> 5149         return self.node_by_name(node_name)
#    5150
#    5151     def nodes_of_type(self, node_class):
#
# ~\Miniconda3\envs\DAVE\lib\site-packages\DAVE\scene.py in node_by_name(self, node_name, silent)
#    5143         if not silent:
#    5144             self.print_node_tree()
# -> 5145         raise ValueError('No node with name "{}". Available names printed above.'.format(node_name))
#    5146
#    5147     def __getitem__(self, node_name):
#
# ValueError: No node with name "Axis". Available names printed above.

# %%
print('test')

# %%
from DAVE.jupyter import *

# %%
show(s, sea = False, camera_pos = (17.897131304435963, -28.090264980131806, 16.92501149181301), lookat = (3.4635498226127215, 2.313446955034758, 2.0246601765435708), force_normalize = True, force_scale = 1.6)
