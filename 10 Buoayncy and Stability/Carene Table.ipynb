# %% [markdown]
# # Derive a carene table from a buoyancy shape

# %%
from DAVE import *
from DAVE.jupyter import *
# Out:
# embedWindow(verbose=True): could not load k3d module, try:
# > pip install k3d      # and if necessary:
# > conda install nodejs

# %%
s = Scene("cheetah.dave")  # use the Cheetah model
# Out:
# Loading C:\Users\beneden\Miniconda3\envs\DAVE\lib\site-packages\DAVE\resources\cheetah.dave

# %% [markdown]
# Have a look at the names of the nodes

# %%
show(s, sea = True, camera_pos = (377.41378393620676, 177.29136875029081, -22.319832341170876), lookat = (52.20246063341496, -52.124244707385635, 2.968568242388601), force_normalize = True, force_scale = 1.6, cog_scale = 0)
# Out:
# <PIL.Image.Image image mode=RGB size=3072x1800 at 0x2206ACC3760>

# %%
s.print_node_tree()
# Out:
# Cheetah [RigidBody]
#  |-> DP reference point [Axis]
#  |-> buoyancy [Buoyancy]
#  |-> Ballast_system [BallastSystem]
#  |-> visual - vessel [Visual]
#  |-> Wave Interaction draft 6.75 [WaveInteraction1]
# DP setpoint for cheetah [Axis]
# DP springs cheetah [LC6d]

# %%
from DAVE.marine import carene_table

# %% [markdown]
# ## Calculate the carene table
#
# - The carene curve is requested based on the buoyancy node [Buoyancy], not the vessel node !
# - The table is calculated numerically using a small displacement from the even-keel situation.

# %%
node = s['buoyancy']
table = carene_table(s, node, draft_min = 0.25, draft_max = 9, stepsize=.5)

# %%
table
# Out:
#              BM T [m]     BM L [m]   CoF x [m]     CoF y [m]    Awl [m2]  \
# Draft [m]
# 0.25       549.000884  5942.565819  112.103608  7.784851e-07  600.499598
# 0.75       214.740826  2708.765262  112.158916  7.381401e-07  661.834544
# 1.25       130.593750  1821.963021  110.752916  6.860430e-07  699.051892
# 1.75        94.702157  1427.590275  108.768755  5.794678e-07  731.154060
# 2.25        74.717759  1207.275426  106.610463  3.926401e-07  758.879825
# 2.75        62.134729  1063.599542  104.621392  1.580715e-07  784.017712
# 3.25        53.585599   963.068462  102.559857 -1.063507e-07  809.511263
# 3.75        47.096220   890.022494  100.988847 -3.203614e-07  830.173195
# 4.25        41.817434   811.018803  100.184583 -4.420001e-07  843.085513
# 4.75        37.577242   739.073867   99.630973 -5.291604e-07  853.516374
# 5.25        34.110135   676.705102   99.263550 -6.045918e-07  861.952335
# 5.75        31.230735   622.289585   99.057960 -6.704610e-07  868.436442
# 6.25        28.795489   573.510202   98.995541 -7.008935e-07  873.336992
# 6.75        26.701756   530.195841   98.945439 -7.075419e-07  877.308077
# 7.25        24.890992   493.912250   98.877519 -7.129828e-07  880.461119
# 7.75        23.309345   462.837639   98.939135 -7.008420e-07  884.011126
# 8.25        21.926919   435.770401   99.013007 -6.878314e-07  887.526576
# 8.75        20.708067   412.041705   99.110367 -6.732595e-07  890.957856
# 9.00        20.150536   401.183663   99.166632 -6.646144e-07  892.633133
#
#            Displacement [m3]   CoB x [m]     CoB y [m]  CoB z [m]
# Draft [m]
# 0.25              138.797161  111.616555  7.311428e-07   0.129644
# 0.75              456.758328  112.173159  7.549822e-07   0.390179
# 1.25              797.270424  111.897894  7.388329e-07   0.651599
# 1.75             1155.032508  111.246751  7.080090e-07   0.914965
# 2.25             1527.653295  110.375567  6.549477e-07   1.180002
# 2.75             1913.446741  109.412334  5.787125e-07   1.446416
# 3.25             2311.759180  108.411198  4.836934e-07   1.714326
# 3.75             2722.314751  107.389634  3.765399e-07   1.983785
# 4.25             3140.734701  106.480040  2.750674e-07   2.252478
# 4.75             3564.973855  105.695682  1.843714e-07   2.519999
# 5.25             3993.919004  105.023216  1.036123e-07   2.786394
# 5.75             4426.611321  104.448162  3.100982e-08   3.051674
# 6.25             4862.106460  103.962116 -3.379685e-08   3.315775
# 6.75             5299.794622  103.550093 -8.910007e-08   3.578762
# 7.25             5739.212842  103.193850 -1.368045e-07   3.840718
# 7.75             6180.332790  102.887864 -1.775121e-07   4.101910
# 8.25             6623.215455  102.626185 -2.120737e-07   4.362579
# 8.75             7067.839842  102.401803 -2.415569e-07   4.622867
# 9.00             7290.788433  102.302008 -2.546337e-07   4.752896

# %% [markdown]
# ## Plotting
#
# First re-generate the table with a smaller set-size:

# %%
table = carene_table(s, node, draft_min = 0.25, draft_max = 9, stepsize=.1)

# %% [markdown]
# By default the table in indexed by draft. This means the plot methods will plot with draft on the x-axis:

# %%
# Set matplotlib figure size
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [10, 6]

table.plot();

# %% [markdown]
# To be able to plot with in the traditional way with the draft vertical we need to reset the index.
# The x and y can then be specified by name

# %%
table = table.reset_index()
table.plot(x = 'CoF x [m]', y= 'Draft [m]')
plt.grid()

# %% [markdown]
# For plotting multiple lines in the same graph it is easiest to create the plots using matplotlib directly.

# %%
draft = table['Draft [m]']
cofx = table['CoF x [m]']
cobx = table['CoB x [m]']

plt.plot(cofx, draft,label='CoF x [m]')
plt.plot(cobx, draft,label='CoB x [m]')
plt.grid()
plt.legend();

# %% [markdown]
# Observe that the CoBx line is vertical at the point where CoBx = CoFx. Does that make sense?

# %% [markdown]
# -- done --
